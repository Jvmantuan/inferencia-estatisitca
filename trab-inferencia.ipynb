# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pops.txt', sep=' ')

# %% [markdown]
# # População 1

# %%
sns.distplot(df['x1'], bins=30, color='r')

# %% [markdown]
# **Média e variância da população**

# %%
df['x1'].mean()
# Out:
# 0.400030312200002

# %%
df['x1'].var()
# Out:
# 0.08010447144712333

# %% [markdown]
# # População 2

# %%
sns.distplot(df['x2'],bins=30)

# %% [markdown]
# **Média e variância da população**

# %%
df['x2'].mean()
# Out:
# 499.9464750013961

# %%
df['x2'].var()
# Out:
# 2499.660584483271

# %% [markdown]
# # População 3

# %%
sns.distplot(df['x3'], bins=30, color='g')

# %% [markdown]
# **Média e variância da população**

# %%
df['x3'].mean()
# Out:
# 0.9090231626001246

# %%
df['x3'].var()
# Out:
# 0.012731906205469547

# %% [markdown]
# # População 4

# %%
sns.distplot(df['x4'], bins=30, color='orange')

# %% [markdown]
# **Média e variância da população**

# %%
df['x4'].mean()
# Out:
# 74.9976198380992

# %%
df['x4'].var()
# Out:
# 74.97691980608178
